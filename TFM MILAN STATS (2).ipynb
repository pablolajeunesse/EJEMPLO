# %% [markdown]
# #             <span style="color: red;">DATA SCIENCE PROJECT: RECONSTRUCTING AC MILAN</span>

# %% [markdown]
# Not too long ago, AC Milan was considered the best team in Italy and one of the best teams in the world. With a total of 52 official titles including 18 Serie A, 2 Serie B, 5 Italian Cups, 7 Italian Supercups, 7 UEFA Champions Leagues (making them the second team with most Champions Leagues in history, only falling behind Real Madrid with 13), 3 intercontinental Cups, 1 FIFA Club World Cup, 2 UEFA Cup Winners Cups amongst other important trophies, this historical club had always had the best football superstars when it came to players and coaches, and had must definitely always been a team to fear when played against.
#
# However, this winning tendency started to change approximately 10-11 years ago after their last italian Serie A title in the 2010-11 season (on that year, they also lifted the italian Supercup). Since that season, AC Milan has only won one italian Supercup in 2016 and has been to the italian Cup final twice (2015-16 and 2017-18), losing both times.
#
# After their last winning season in 2010-11 the team never changed nor rightfully reconstructed its roster, while other teams like Juventus, Nápoli or even Roma kept building their way up, signing and bringing great players and thus improving their squads. Then, they slowly started losing their best players (like Zlatan Ibrahimovic in attack and Thiago Silva in defence), and the economic crisis hit them hard, leaving them with financial problems and less money to improve their team during the transfer windows.
#
# Today, the reality is that AC Milan is no more than a struggling club which last qualified to UEFA Champions League in the 2012-2013 season (so 7 years ago, when they finished 3rd in Italian Serie A, which was the last spot required in order to qualify for the prestigious European tournament for the next season, until the rules changed in 2017-2018 allowing the 4th in the table to qualify as well), and most importantly a club which has completely lost the respect and fear effect from its rivals.
#
# The objective of this project will be to use data analysis to try and find out what AC Milan needs (footballingly and statistically speaking) to improve in order to make it back to UEFA Champions League spots in italian Serie A (only the top 3 teams of each league qualify to Champions League each season). We will analyze, compare, and visualize AC Milan's football statistics from the last time they qualified to UEFA Champions League (2012-13 season) until their last completed season (2018-2019).
# We will also compare Milan's stats to those of teams which did qualify to UEFA Champions League, using them as a reference and Key Performance Indicators Milan will have to imitate and reach in order to get back to the prestigious european competition.

# %% [markdown]
# ## LOADING, CLEANING AND PREPARING DATA:
#
# For the purpose of this project, we downloaded csv files from footystats.org containing statistical data we wish to analyze for the study of our topic.

# %%
#we load the pandas and read the csv file:

import pandas as pd

TeamsData = pd.read_csv("italy-serie-a-teams-2012-to-2013-stats.csv")
pd.options.display.max_columns = None
TeamsData.head()
# Out:
#          team_name common_name     season country  matches_played  \
# 0       SSC Napoli      Napoli  2012/2013   Italy              38
# 1      Juventus FC    Juventus  2012/2013   Italy              38
# 2          AS Roma        Roma  2012/2013   Italy              38
# 3  Cagliari Calcio    Cagliari  2012/2013   Italy              38
# 4        Torino FC      Torino  2012/2013   Italy              38
#
#    matches_played_home  matches_played_away  suspended_matches  wins  \
# 0                   19                   19                  0    23
# 1                   19                   19                  0    27
# 2                   19                   19                  0    18
# 3                   19                   19                  0    12
# 4                   19                   19                  0     8
#
#    wins_home  wins_away  draws  draws_home  draws_away  losses  losses_home  \
# ...

# %%
TeamsData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Columns: 280 entries, team_name to goals_conceded_min_81_to_90
# dtypes: float64(30), int64(246), object(4)
# memory usage: 43.8+ KB

# %%
#We have a look at all the columns:

for col in TeamsData.columns:
    print(col)
# Out:
# team_name
# common_name
# season
# country
# matches_played
# matches_played_home
# matches_played_away
# suspended_matches
# wins
# wins_home
# wins_away
# draws
# draws_home
# draws_away
# losses
# losses_home
# losses_away
# points_per_game
# points_per_game_home
# points_per_game_away
# league_position
# league_position_home
# league_position_away
# performance_rank
# goals_scored
# goals_conceded
# goal_difference
# total_goal_count
# total_goal_count_home
# total_goal_count_away
# goals_scored_home
# goals_scored_away
# goals_conceded_home
# goals_conceded_away
# goal_difference_home
# goal_difference_away
# minutes_per_goal_scored
# minutes_per_goal_scored_home
# minutes_per_goal_scored_away
# minutes_per_goal_conceded
# minutes_per_goal_conceded_home
# minutes_per_goal_conceded_away
# clean_sheets
# clean_sheets_home
# clean_sheets_away
# btts_count
# btts_count_home
# btts_count_away
# fts_count
# fts_count_home
# fts_count_away
# first_team_to_score_count
# ...

# %%
#create new dataset with columns we will use for the exercise and rename them
#display data according to position of team in the league:

TeamsData_1213 = TeamsData[['season', 'league_position', 'team_name', 'points_per_game', 'matches_played', 'wins', 'draws', 'losses','goals_scored', 'goals_conceded', 'goal_difference', 'clean_sheets', 'fts_count', 'goals_scored_per_match', 'goals_conceded_per_match', 'win_percentage', 'clean_sheet_percentage', 'fts_percentage', 'cards_total', 'average_possession', 'shots', 'shots_on_target', 'shots_off_target', 'fouls',]].sort_values(by='league_position', ascending=True)

TeamsData_1213 = TeamsData_1213.rename(columns = {'season':'Season', 'league_position':'League position', 'team_name':'Team name', 'points_per_game':'Points per game', 'matches_played':'Matches played', 'wins':'Wins', 'draws':'Draws', 'losses':'Losses', 'goals_scored':'Goals scored', 'goals_conceded':'Goals conceded', 'goal_difference':'Goal difference', 'clean_sheets':'Clean sheets', 'fts_count':'Failed to score', 'goals_scored_per_match':'Goals scored per match', 'goals_conceded_per_match':'Goals conceded per match', 'win_percentage':'Win %', 'clean_sheet_percentage':'Clean sheet %', 'fts_percentage':'Failed to score %', 'cards_total':'Number of cards','average_possession':'Average possession', 'shots':'Shots', 'shots_on_target':'Shots on target', 'shots_off_target':'Shots off target', 'fouls':'Fouls'})

TeamsData_1213
# Out:
#        Season  League position                   Team name  Points per game  \
# 1   2012/2013                1                 Juventus FC             2.29
# 0   2012/2013                2                  SSC Napoli             2.05
# 7   2012/2013                3                    AC Milan             1.89
# 16  2012/2013                4              ACF Fiorentina             1.84
# 12  2012/2013                5              Udinese Calcio             1.74
# 2   2012/2013                6                     AS Roma             1.63
# 9   2012/2013                7                    SS Lazio             1.61
# 18  2012/2013                8              Calcio Catania             1.47
# 15  2012/2013                9    FC Internazionale Milano             1.42
# 17  2012/2013               10           Parma Calcio 1913             1.29
# 3   2012/2013               11             Cagliari Calcio             1.24
# ...

# %%
#We calculate the number of points the teams ended the 2012-2013 season with
#by multiplying their Wins by 3 (as every win is worth 3 points) and adding
#the draws to that (as each draw is worth 1 point). 
#We then add the new column named 'Total points' to the dataset:

TeamsData_1213['Total points'] = TeamsData_1213['Wins']*3 + TeamsData_1213['Draws']
TeamsData_1213 = TeamsData_1213[['Season', 'League position', 'Team name', 'Total points', 'Points per game', 'Matches played', 'Wins', 'Draws', 'Losses', 'Goals scored', 'Goals conceded', 'Goal difference', 'Clean sheets', 'Failed to score', 'Goals scored per match', 'Goals conceded per match', 'Win %', 'Clean sheet %', 'Failed to score %', 'Number of cards', 'Average possession', 'Shots', 'Shots on target', 'Shots off target', 'Fouls']]

TeamsData_1213
# Out:
#        Season  League position                   Team name  Total points  \
# 1   2012/2013                1                 Juventus FC            87
# 0   2012/2013                2                  SSC Napoli            78
# 7   2012/2013                3                    AC Milan            72
# 16  2012/2013                4              ACF Fiorentina            70
# 12  2012/2013                5              Udinese Calcio            66
# 2   2012/2013                6                     AS Roma            62
# 9   2012/2013                7                    SS Lazio            61
# 18  2012/2013                8              Calcio Catania            56
# 15  2012/2013                9    FC Internazionale Milano            54
# 17  2012/2013               10           Parma Calcio 1913            49
# 3   2012/2013               11             Cagliari Calcio            47
# 14  2012/2013               12            AC Chievo Verona            45
# ...

# %%
#We create a dataset with AC Milan's statistics for the 2012-13 season: 

ACMilan1213 = TeamsData_1213.loc[TeamsData_1213['Team name'] == 'AC Milan']

ACMilan1213
# Out:
#       Season  League position Team name  Total points  Points per game  \
# 7  2012/2013                3  AC Milan            72             1.89
#
#    Matches played  Wins  Draws  Losses  Goals scored  Goals conceded  \
# 7              38    21      9       8            67              39
#
#    Goal difference  Clean sheets  Failed to score  Goals scored per match  \
# 7               28            12                6                    1.76
#
#    Goals conceded per match  Win %  Clean sheet %  Failed to score %  \
# 7                      1.03     55             32                 16
#
#    Number of cards  Average possession  Shots  Shots on target  \
# 7              105                  -1    634              285
#
#    Shots off target  Fouls
# 7               349    514

# %%
#We do the same exact process for all of the other seasons:

#Season 2013-14:

TeamsData = pd.read_csv("italy-serie-a-teams-2013-to-2014-stats.csv")
pd.options.display.max_columns = None

TeamsData_1314 = TeamsData[['season', 'league_position', 'team_name', 'points_per_game', 'matches_played', 'wins', 'draws', 'losses','goals_scored', 'goals_conceded', 'goal_difference', 'clean_sheets', 'fts_count', 'goals_scored_per_match', 'goals_conceded_per_match', 'win_percentage', 'clean_sheet_percentage', 'fts_percentage', 'cards_total', 'average_possession', 'shots', 'shots_on_target', 'shots_off_target', 'fouls',]].sort_values(by='league_position', ascending=True)
TeamsData_1314 = TeamsData_1314.rename(columns = {'season':'Season', 'league_position':'League position', 'team_name':'Team name', 'points_per_game':'Points per game', 'matches_played':'Matches played', 'wins':'Wins', 'draws':'Draws', 'losses':'Losses', 'goals_scored':'Goals scored', 'goals_conceded':'Goals conceded', 'goal_difference':'Goal difference', 'clean_sheets':'Clean sheets', 'fts_count':'Failed to score', 'goals_scored_per_match':'Goals scored per match', 'goals_conceded_per_match':'Goals conceded per match', 'win_percentage':'Win %', 'clean_sheet_percentage':'Clean sheet %', 'fts_percentage':'Failed to score %', 'cards_total':'Number of cards','average_possession':'Average possession', 'shots':'Shots', 'shots_on_target':'Shots on target', 'shots_off_target':'Shots off target', 'fouls':'Fouls'})

TeamsData_1314['Total points'] = TeamsData_1314['Wins']*3 + TeamsData_1314['Draws']
TeamsData_1314 = TeamsData_1314[['Season', 'League position', 'Team name', 'Total points', 'Points per game', 'Matches played', 'Wins', 'Draws', 'Losses', 'Goals scored', 'Goals conceded', 'Goal difference', 'Clean sheets', 'Failed to score', 'Goals scored per match', 'Goals conceded per match', 'Win %', 'Clean sheet %', 'Failed to score %', 'Number of cards', 'Average possession', 'Shots', 'Shots on target', 'Shots off target', 'Fouls']]

ACMilan1314 = TeamsData_1314.loc[TeamsData_1314['Team name'] == 'AC Milan']


#Season 2014-15:

TeamsData = pd.read_csv("italy-serie-a-teams-2014-to-2015-stats.csv")
pd.options.display.max_columns = None

TeamsData_1415 = TeamsData[['season', 'league_position', 'team_name', 'points_per_game', 'matches_played', 'wins', 'draws', 'losses','goals_scored', 'goals_conceded', 'goal_difference', 'clean_sheets', 'fts_count', 'goals_scored_per_match', 'goals_conceded_per_match', 'win_percentage', 'clean_sheet_percentage', 'fts_percentage', 'cards_total', 'average_possession', 'shots', 'shots_on_target', 'shots_off_target', 'fouls',]].sort_values(by='league_position', ascending=True)
TeamsData_1415 = TeamsData_1415.rename(columns = {'season':'Season', 'league_position':'League position', 'team_name':'Team name', 'points_per_game':'Points per game', 'matches_played':'Matches played', 'wins':'Wins', 'draws':'Draws', 'losses':'Losses', 'goals_scored':'Goals scored', 'goals_conceded':'Goals conceded', 'goal_difference':'Goal difference', 'clean_sheets':'Clean sheets', 'fts_count':'Failed to score', 'goals_scored_per_match':'Goals scored per match', 'goals_conceded_per_match':'Goals conceded per match', 'win_percentage':'Win %', 'clean_sheet_percentage':'Clean sheet %', 'fts_percentage':'Failed to score %', 'cards_total':'Number of cards','average_possession':'Average possession', 'shots':'Shots', 'shots_on_target':'Shots on target', 'shots_off_target':'Shots off target', 'fouls':'Fouls'})

TeamsData_1415['Total points'] = TeamsData_1415['Wins']*3 + TeamsData_1415['Draws']
TeamsData_1415 = TeamsData_1415[['Season', 'League position', 'Team name', 'Total points', 'Points per game', 'Matches played', 'Wins', 'Draws', 'Losses', 'Goals scored', 'Goals conceded', 'Goal difference', 'Clean sheets', 'Failed to score', 'Goals scored per match', 'Goals conceded per match', 'Win %', 'Clean sheet %', 'Failed to score %', 'Number of cards', 'Average possession', 'Shots', 'Shots on target', 'Shots off target', 'Fouls']]

ACMilan1415 = TeamsData_1415.loc[TeamsData_1415['Team name'] == 'AC Milan']


#Season 2015-16:

TeamsData = pd.read_csv("italy-serie-a-teams-2015-to-2016-stats.csv")
pd.options.display.max_columns = None

TeamsData_1516 = TeamsData[['season', 'league_position', 'team_name', 'points_per_game', 'matches_played', 'wins', 'draws', 'losses','goals_scored', 'goals_conceded', 'goal_difference', 'clean_sheets', 'fts_count', 'goals_scored_per_match', 'goals_conceded_per_match', 'win_percentage', 'clean_sheet_percentage', 'fts_percentage', 'cards_total', 'average_possession', 'shots', 'shots_on_target', 'shots_off_target', 'fouls',]].sort_values(by='league_position', ascending=True)
TeamsData_1516 = TeamsData_1516.rename(columns = {'season':'Season', 'league_position':'League position', 'team_name':'Team name', 'points_per_game':'Points per game', 'matches_played':'Matches played', 'wins':'Wins', 'draws':'Draws', 'losses':'Losses', 'goals_scored':'Goals scored', 'goals_conceded':'Goals conceded', 'goal_difference':'Goal difference', 'clean_sheets':'Clean sheets', 'fts_count':'Failed to score', 'goals_scored_per_match':'Goals scored per match', 'goals_conceded_per_match':'Goals conceded per match', 'win_percentage':'Win %', 'clean_sheet_percentage':'Clean sheet %', 'fts_percentage':'Failed to score %', 'cards_total':'Number of cards','average_possession':'Average possession', 'shots':'Shots', 'shots_on_target':'Shots on target', 'shots_off_target':'Shots off target', 'fouls':'Fouls'})

TeamsData_1516['Total points'] = TeamsData_1516['Wins']*3 + TeamsData_1516['Draws']
TeamsData_1516 = TeamsData_1516[['Season', 'League position', 'Team name', 'Total points', 'Points per game', 'Matches played', 'Wins', 'Draws', 'Losses', 'Goals scored', 'Goals conceded', 'Goal difference', 'Clean sheets', 'Failed to score', 'Goals scored per match', 'Goals conceded per match', 'Win %', 'Clean sheet %', 'Failed to score %', 'Number of cards', 'Average possession', 'Shots', 'Shots on target', 'Shots off target', 'Fouls']]

ACMilan1516 = TeamsData_1516.loc[TeamsData_1516['Team name'] == 'AC Milan']


#Season 2016-17:

TeamsData = pd.read_csv("italy-serie-a-teams-2016-to-2017-stats.csv")
pd.options.display.max_columns = None

TeamsData_1617 = TeamsData[['season', 'league_position', 'team_name', 'points_per_game', 'matches_played', 'wins', 'draws', 'losses','goals_scored', 'goals_conceded', 'goal_difference', 'clean_sheets', 'fts_count', 'goals_scored_per_match', 'goals_conceded_per_match', 'win_percentage', 'clean_sheet_percentage', 'fts_percentage', 'cards_total', 'average_possession', 'shots', 'shots_on_target', 'shots_off_target', 'fouls',]].sort_values(by='league_position', ascending=True)
TeamsData_1617 = TeamsData_1617.rename(columns = {'season':'Season', 'league_position':'League position', 'team_name':'Team name', 'points_per_game':'Points per game', 'matches_played':'Matches played', 'wins':'Wins', 'draws':'Draws', 'losses':'Losses', 'goals_scored':'Goals scored', 'goals_conceded':'Goals conceded', 'goal_difference':'Goal difference', 'clean_sheets':'Clean sheets', 'fts_count':'Failed to score', 'goals_scored_per_match':'Goals scored per match', 'goals_conceded_per_match':'Goals conceded per match', 'win_percentage':'Win %', 'clean_sheet_percentage':'Clean sheet %', 'fts_percentage':'Failed to score %', 'cards_total':'Number of cards','average_possession':'Average possession', 'shots':'Shots', 'shots_on_target':'Shots on target', 'shots_off_target':'Shots off target', 'fouls':'Fouls'})

TeamsData_1617['Total points'] = TeamsData_1617['Wins']*3 + TeamsData_1617['Draws']
TeamsData_1617 = TeamsData_1617[['Season', 'League position', 'Team name', 'Total points', 'Points per game', 'Matches played', 'Wins', 'Draws', 'Losses', 'Goals scored', 'Goals conceded', 'Goal difference', 'Clean sheets', 'Failed to score', 'Goals scored per match', 'Goals conceded per match', 'Win %', 'Clean sheet %', 'Failed to score %', 'Number of cards', 'Average possession', 'Shots', 'Shots on target', 'Shots off target', 'Fouls']]

ACMilan1617 = TeamsData_1617.loc[TeamsData_1617['Team name'] == 'AC Milan']


#Season 2017-18:

TeamsData = pd.read_csv("italy-serie-a-teams-2017-to-2018-stats.csv")
pd.options.display.max_columns = None

TeamsData_1718 = TeamsData[['season', 'league_position', 'team_name', 'points_per_game', 'matches_played', 'wins', 'draws', 'losses','goals_scored', 'goals_conceded', 'goal_difference', 'clean_sheets', 'fts_count', 'goals_scored_per_match', 'goals_conceded_per_match', 'win_percentage', 'clean_sheet_percentage', 'fts_percentage', 'cards_total', 'average_possession', 'shots', 'shots_on_target', 'shots_off_target', 'fouls',]].sort_values(by='league_position', ascending=True)
TeamsData_1718 = TeamsData_1718.rename(columns = {'season':'Season', 'league_position':'League position', 'team_name':'Team name', 'points_per_game':'Points per game', 'matches_played':'Matches played', 'wins':'Wins', 'draws':'Draws', 'losses':'Losses', 'goals_scored':'Goals scored', 'goals_conceded':'Goals conceded', 'goal_difference':'Goal difference', 'clean_sheets':'Clean sheets', 'fts_count':'Failed to score', 'goals_scored_per_match':'Goals scored per match', 'goals_conceded_per_match':'Goals conceded per match', 'win_percentage':'Win %', 'clean_sheet_percentage':'Clean sheet %', 'fts_percentage':'Failed to score %', 'cards_total':'Number of cards','average_possession':'Average possession', 'shots':'Shots', 'shots_on_target':'Shots on target', 'shots_off_target':'Shots off target', 'fouls':'Fouls'})

TeamsData_1718['Total points'] = TeamsData_1718['Wins']*3 + TeamsData_1718['Draws']
TeamsData_1718 = TeamsData_1718[['Season', 'League position', 'Team name', 'Total points', 'Points per game', 'Matches played', 'Wins', 'Draws', 'Losses', 'Goals scored', 'Goals conceded', 'Goal difference', 'Clean sheets', 'Failed to score', 'Goals scored per match', 'Goals conceded per match', 'Win %', 'Clean sheet %', 'Failed to score %', 'Number of cards', 'Average possession', 'Shots', 'Shots on target', 'Shots off target', 'Fouls']]

ACMilan1718 = TeamsData_1718.loc[TeamsData_1718['Team name'] == 'AC Milan']


#Season 2018-19:

TeamsData = pd.read_csv("italy-serie-a-teams-2018-to-2019-stats.csv")
pd.options.display.max_columns = None

TeamsData_1819 = TeamsData[['season', 'league_position', 'team_name', 'points_per_game', 'matches_played', 'wins', 'draws', 'losses','goals_scored', 'goals_conceded', 'goal_difference', 'clean_sheets', 'fts_count', 'goals_scored_per_match', 'goals_conceded_per_match', 'win_percentage', 'clean_sheet_percentage', 'fts_percentage', 'cards_total', 'average_possession', 'shots', 'shots_on_target', 'shots_off_target', 'fouls',]].sort_values(by='league_position', ascending=True)
TeamsData_1819 = TeamsData_1819.rename(columns = {'season':'Season', 'league_position':'League position', 'team_name':'Team name', 'points_per_game':'Points per game', 'matches_played':'Matches played', 'wins':'Wins', 'draws':'Draws', 'losses':'Losses', 'goals_scored':'Goals scored', 'goals_conceded':'Goals conceded', 'goal_difference':'Goal difference', 'clean_sheets':'Clean sheets', 'fts_count':'Failed to score', 'goals_scored_per_match':'Goals scored per match', 'goals_conceded_per_match':'Goals conceded per match', 'win_percentage':'Win %', 'clean_sheet_percentage':'Clean sheet %', 'fts_percentage':'Failed to score %', 'cards_total':'Number of cards','average_possession':'Average possession', 'shots':'Shots', 'shots_on_target':'Shots on target', 'shots_off_target':'Shots off target', 'fouls':'Fouls'})

TeamsData_1819['Total points'] = TeamsData_1819['Wins']*3 + TeamsData_1819['Draws']
TeamsData_1819 = TeamsData_1819[['Season', 'League position', 'Team name', 'Total points', 'Points per game', 'Matches played', 'Wins', 'Draws', 'Losses', 'Goals scored', 'Goals conceded', 'Goal difference', 'Clean sheets', 'Failed to score', 'Goals scored per match', 'Goals conceded per match', 'Win %', 'Clean sheet %', 'Failed to score %', 'Number of cards', 'Average possession', 'Shots', 'Shots on target', 'Shots off target', 'Fouls']]

ACMilan1819 = TeamsData_1819.loc[TeamsData_1819['Team name'] == 'AC Milan']

# %%
#We create a new DataFrame showing only Milan's stats for every season (from 2012-2019),
#sorting them by season in ascending order:

Data_ACMilan = pd.concat([ACMilan1213, ACMilan1314, ACMilan1415, ACMilan1516, ACMilan1617, ACMilan1718, ACMilan1819]).sort_values(by='Season', ascending=True)

Data_ACMilan
# Out:
#       Season  League position Team name  Total points  Points per game  \
# 7  2012/2013                3  AC Milan            72             1.89
# 6  2013/2014                8  AC Milan            57             1.50
# 7  2014/2015               10  AC Milan            52             1.37
# 6  2015/2016                7  AC Milan            57             1.50
# 9  2016/2017                6  AC Milan            63             1.66
# 7  2017/2018                6  AC Milan            64             1.68
# 7  2018/2019                5  AC Milan            68             1.79
#
#    Matches played  Wins  Draws  Losses  Goals scored  Goals conceded  \
# 7              38    21      9       8            67              39
# 6              38    16      9      13            57              49
# 7              38    13     13      12            56              50
# 6              38    15     12      11            49              43
# ...

# %%
#We create yet another DataFrame with the Stats of the teams which finished in 3rd position each season.
#As stated in the introduction, only the top 3 teams make it to Champions League each season, 
#meaning these stats were the "minimum requirements" in order to qualify for Champions League the following season:

CLStats201213 = TeamsData_1213.loc[TeamsData_1213['League position'] == 3]
CLStats201314 = TeamsData_1314.loc[TeamsData_1314['League position'] == 3]
CLStats201415 = TeamsData_1415.loc[TeamsData_1415['League position'] == 3]
CLStats201516 = TeamsData_1516.loc[TeamsData_1516['League position'] == 3]
CLStats201617 = TeamsData_1617.loc[TeamsData_1617['League position'] == 3]
CLStats201718 = TeamsData_1718.loc[TeamsData_1718['League position'] == 3]
CLStats201819 = TeamsData_1819.loc[TeamsData_1819['League position'] == 3]

Data_CLStats = pd.concat([CLStats201213, CLStats201314, CLStats201415, CLStats201516, CLStats201617, CLStats201718, CLStats201819]).sort_values(by='Season', ascending=True)

Data_CLStats
# Out:
#       Season  League position                   Team name  Total points  \
# 7  2012/2013                3                    AC Milan            72
# 0  2013/2014                3                  SSC Napoli            78
# 9  2014/2015                3                    SS Lazio            69
# 2  2015/2016                3                     AS Roma            80
# 0  2016/2017                3                  SSC Napoli            86
# 2  2017/2018                3                     AS Roma            77
# 9  2018/2019                3  Atalanta Bergamasca Calcio            69
#
#    Points per game  Matches played  Wins  Draws  Losses  Goals scored  \
# 7             1.89              38    21      9       8            67
# 0             2.05              38    23      9       6            77
# 9             1.82              38    21      6      11            71
# 2             2.11              38    23     11       4            83
# ...

# %% [markdown]
# ## ANALYZING/VIZUALISING/COMPARING DATA:

# %%
#Representation of Milans total points vs those of the 3rd in the league for each season. 
#We will call these teams "UCL team" as 3rd in the table is the limit/last spot to qualify for Champions League:

import matplotlib.pyplot as plt
from matplotlib.pyplot import figure


plt.figure(figsize=(16,5))
plt.plot(Data_ACMilan['Season'], Data_ACMilan['Total points'], color='r', marker='o', label='Milans points')
plt.plot(Data_CLStats['Season'], Data_CLStats['Total points'], color='b', marker='o', label='UCL team points')

plt.title('Milan vs UCL team TOTAL POINTS per season')
plt.xlabel('Seasons')
plt.ylabel('Points')
plt.legend()

for x,y in zip(Data_ACMilan['Season'], Data_ACMilan['Total points']):
    label = "{:} pts".format(y)
    plt.annotate(label, (x,y), textcoords='offset points', xytext=(0, 10), ha='center')
    
for x,y in zip(Data_CLStats['Season'], Data_CLStats['Total points']):
    label = "{:} pts".format(y)
    plt.annotate(label, (x,y), textcoords='offset points', xytext=(0, 10), ha='center')

# %% [markdown]
# The plot above is a representation of Milan vs UCL teams total points per season.

# %%
#Milan vs UCL team points per game for each season: 

import matplotlib.pyplot as plt
from matplotlib.pyplot import figure


plt.figure(figsize=(16,5))
plt.plot(Data_ACMilan['Season'], Data_ACMilan['Points per game'], color='r', marker='o', label='Milans points per game')
plt.plot(Data_CLStats['Season'], Data_CLStats['Points per game'], color='b', marker='o', label='UCL team points per game')

plt.title('Milan vs UCL team points per game by season')
plt.xlabel('Seasons')
plt.ylabel('Points per game')
plt.legend()

for x,y in zip(Data_ACMilan['Season'], Data_ACMilan['Points per game']):
    label = "{:}".format(y)
    plt.annotate(label, (x,y), textcoords='offset points', xytext=(0, 10), ha='center')
    
for x,y in zip(Data_CLStats['Season'], Data_CLStats['Points per game']):
    label = "{:}".format(y)
    plt.annotate(label, (x,y), textcoords='offset points', xytext=(0, 10), ha='center')

# %% [markdown]
# The plot above is a representation of Milan vs UCL teams points per game each season.

# %% [markdown]
# These first two graphs help us visualize how big the gap between Milan and the 3rd in Serie A league's table was for most of the last 7 seasons. Besides the 2012-2013 season, which is when Milan last qualified for Champions League, and the 2018-2019 season, when they fell short by only one point, the closest Milan had been from Champions League spots was 13 points during the 2017-2018 season. This clearly indicates the poor form of the team.
#
# With the following plots, we are going more in depth by showing and comparing Milan vs UCL team stats per season:

# %%
#Compare Milans amount of Wins, Losses, Draws each season to those of UCL Teams:

X = Data_ACMilan[['Season', 'Wins', 'Draws', 'Losses']] 
Y = X.set_index('Season')
Z = Y.groupby('Season').sum()

U = Data_CLStats[['Season', 'Wins', 'Draws', 'Losses']]
C = U.set_index('Season')
L = C.groupby('Season').sum()

XYZ = Z.plot.bar(title='Milans Record per season', stacked=True, figsize=(12,8))
UCL = L.plot.bar(title='UCL team Record per season', stacked=True, figsize=(12,8))

for p in XYZ.patches:
    width, height = p.get_width(), p.get_height()
    x, y = p.get_xy() 
    XYZ.text(x+width/2, 
            y+height/2, 
            '{:}'.format(height), 
            horizontalalignment='center', 
            verticalalignment='center')
    
for p in UCL.patches:
    width, height = p.get_width(), p.get_height()
    x, y = p.get_xy() 
    UCL.text(x+width/2, 
            y+height/2, 
            '{:}'.format(height), 
            horizontalalignment='center', 
            verticalalignment='center')

# %% [markdown]
# The plots above compare Milans amount of Wins, Losses, Draws each season to those of UCL Teams.

# %% [markdown]
# Thanks to these plots we can appreciate Milan's and UCL Team's results each season.
#
# As we can see, Milan hasn't reached 20 wins in a single season since they finished 3rd in 2012-2013, which is when they last qualified for Champions League. On top of that, they lost 10 or more games 5 out of the last 7 seasons.
#
# On the other side, UCL Teams have reached 20 wins or more every single season and have lost 10 or more games only once (the 2014-2015 season).
#
# It is obvious to say Milan should try to win every single game, but a good and realistic objective they should have when starting the season would be aiming at least the 20 wins mark. It is also important to know that losing 10 or more games in a season makes it really difficult for a team to make it to UCL Champions League spots.
#
# In a competition where every single point counts, it is important for a team like AC Milan to know these type of statistics in order to achieve its goals/objectives as a club.
# Once Milan reaches 20 wins & less than 10 losses in a season they will have a shot at Champions League spots.
#
# They came really close the 2018-2019 season, finishing in 5th position with 19 wins and 8 losses. Unfortunately for the club, the 2 teams ahead of them ended the season with one more win, leaving them out of european spots.

# %%
#Goals scored/conceded per match by season:

X = Data_ACMilan[['Season', 'Goals scored per match', 'Goals conceded per match']]
Y = X.set_index('Season')
Z = Y.groupby('Season').sum()

U = Data_CLStats[['Season', 'Goals scored per match', 'Goals conceded per match']]
C = U.set_index('Season')
L = C.groupby('Season').sum()

ax = Z.plot.bar(title='Milan Goals scored & conceded per match by season (38 games)', stacked=False, figsize=(12,8), color=['lime','red'])
ucl = L.plot.bar(title='UCL team Goals scored & conceded per match by season (38 games)', stacked=False, figsize=(12,8), color=['lime','red'])

for p in ax.patches:
    width, height = p.get_width(), p.get_height()
    x, y = p.get_xy() 
    ax.text(x+width/2, 
            y+height/2, 
            '{:}'.format(height),
            horizontalalignment='center',
            verticalalignment='bottom')
for p in ucl.patches:
    width, height = p.get_width(), p.get_height()
    x, y = p.get_xy() 
    ucl.text(x+width/2, 
            y+height/2, 
            '{:}'.format(height),
            horizontalalignment='center',
            verticalalignment='bottom')

# %% [markdown]
# Other important aspects of the game AC Milan should improve are their Goals scored & conceded.
#
# As we can see here, Milan hasn't scored more than 1.5 goals per match since the 2012-2013 season. Besides struggling in the attacking side of the game Milan has conceded almost as much as they have scored making it hard for them to win games, specially when getting scored on (thus the amount of draws and losses each season).
#
# We can see several important and interesting facts in the second plot:
# UCL teams are always around the 2 goals scored/game mark (sometimes more or less, but always very close to 2).
# The only season a team had less than 1.76 goals scored/game was in 2017-2018 when AS Roma finished 3rd in the league with only 1.61 goals scored/game. The difference was that season Roma also had the lowest amount of goals conceded/game in the last 5 to 7 years from a team finishing in that position, conceding only 0.74 goals per game and proving "the best offense is a good defense" is not just a quote; it's a reality.
#
# Another fact is UCL Teams are around the 1 goal condeded/game mark.
#
# Besides having a good defense, being strong in attack allows them to have a good goal difference and thus win games even when conceding.
#
# It is clear AC Milan should improve both in attack and defense to have a better goal difference ratio: aiming to surpass the 2 goals scored/game mark and falling under the 1 goal conceded/per game should be their objectives.

# %% [markdown]
# We will create a new DataFrame containing AC Milan and UCL team's overall stats from 2013-2014 till 2018-2019 season, then plot it to better visualize and understand it better.
#
# With the following polar plot we aim to compare AC Milan's overall statistics with those of UCL teams from 2013-2014 season (as they did qualify in 2012-2013) to 2018-2019 in order to have a better understanding of what Milan is missing and needs to adjust in order to have a better chance to fight for European spots:

# %%
#First we take the DataFrames Data_ACMilan and Data_CLStats and delete the 2012/2013
#season, which is when Milan made it to UCL.
Overall_Data_ACMilan = Data_ACMilan[Data_ACMilan.Season != '2012/2013']
Overall_Data_CLStats = Data_CLStats[Data_CLStats.Season != '2012/2013']

#We then create a new row with the average of every column for each DataFrame:
new_row_Overall_Data_CLStats = {'Season':'2013-2019', 'League position':'3rd', 'Team name':'UCL teams', 'Total points':Overall_Data_CLStats['Total points'].mean(), 'Points per game':Overall_Data_CLStats['Points per game'].mean(), 'Matches played':Overall_Data_CLStats['Matches played'].mean(), 'Wins':Overall_Data_CLStats['Wins'].mean(), 'Draws':Overall_Data_CLStats['Draws'].mean(), 'Losses':Overall_Data_CLStats['Losses'].mean(), 'Goals scored':Overall_Data_CLStats['Goals scored'].mean(), 'Goals conceded':Overall_Data_CLStats['Goals conceded'].mean(), 'Goal difference':Overall_Data_CLStats['Goal difference'].mean(), 'Clean sheets':Overall_Data_CLStats['Clean sheets'].mean(), 'Failed to score':Overall_Data_CLStats['Failed to score'].mean(), 'Goals scored per match':Overall_Data_CLStats['Goals scored per match'].mean(), 'Goals conceded per match':Overall_Data_CLStats['Goals conceded per match'].mean(), 'Win %':Overall_Data_CLStats['Win %'].mean(), 'Clean sheet %':Overall_Data_CLStats['Clean sheet %'].mean(), 'Failed to score %':Overall_Data_CLStats['Failed to score %'].mean(), 'Number of cards':Overall_Data_CLStats['Number of cards'].mean(), 'Average possession':Overall_Data_CLStats['Average possession'].mean(), 'Shots':Overall_Data_CLStats['Shots'].mean(), 'Shots on target':Overall_Data_CLStats['Shots on target'].mean(), 'Shots off target':Overall_Data_CLStats['Shots off target'].mean(), 'Fouls':Overall_Data_CLStats['Fouls'].mean()}
new_row_Overall_Data_ACMilan = {'Season':'2013-2019', 'League position':'NA', 'Team name':'AC Milan', 'Total points':Overall_Data_ACMilan['Total points'].mean(), 'Points per game':Overall_Data_ACMilan['Points per game'].mean(), 'Matches played':Overall_Data_ACMilan['Matches played'].mean(), 'Wins':Overall_Data_ACMilan['Wins'].mean(), 'Draws':Overall_Data_ACMilan['Draws'].mean(), 'Losses':Overall_Data_ACMilan['Losses'].mean(), 'Goals scored':Overall_Data_ACMilan['Goals scored'].mean(), 'Goals conceded':Overall_Data_ACMilan['Goals conceded'].mean(), 'Goal difference':Overall_Data_ACMilan['Goal difference'].mean(), 'Clean sheets':Overall_Data_ACMilan['Clean sheets'].mean(), 'Failed to score':Overall_Data_ACMilan['Failed to score'].mean(), 'Goals scored per match':Overall_Data_ACMilan['Goals scored per match'].mean(), 'Goals conceded per match':Overall_Data_ACMilan['Goals conceded per match'].mean(), 'Win %':Overall_Data_ACMilan['Win %'].mean(), 'Clean sheet %':Overall_Data_ACMilan['Clean sheet %'].mean(), 'Failed to score %':Overall_Data_ACMilan['Failed to score %'].mean(), 'Number of cards':Overall_Data_ACMilan['Number of cards'].mean(), 'Average possession':Overall_Data_ACMilan['Average possession'].mean(), 'Shots':Overall_Data_ACMilan['Shots'].mean(), 'Shots on target':Overall_Data_ACMilan['Shots on target'].mean(), 'Shots off target':Overall_Data_ACMilan['Shots off target'].mean(), 'Fouls':Overall_Data_ACMilan['Fouls'].mean()}

#We finally append the rows to their respective DataFrames (as the last row)
#to see both the stats per season and the overall stats for the 6 seasons combined:
Overall_Data_CLStats = Overall_Data_CLStats.append(new_row_Overall_Data_CLStats, ignore_index=True)
Overall_Data_ACMilan = Overall_Data_ACMilan.append(new_row_Overall_Data_ACMilan, ignore_index=True)

#We create the columns "Conversion rate of shots" and "Conversion rate of shots on target"
#to analyze the effectiveness of the team when it comes to shots taken:
Overall_Data_CLStats['Conversion rate of shots'] = (Overall_Data_CLStats['Goals scored'] / Overall_Data_CLStats['Shots'])*100
Overall_Data_CLStats['Conversion rate of shots on target'] = (Overall_Data_CLStats['Goals scored'] / Overall_Data_CLStats['Shots on target'])*100

Overall_Data_ACMilan['Conversion rate of shots'] = (Overall_Data_ACMilan['Goals scored'] / Overall_Data_ACMilan['Shots'])*100
Overall_Data_ACMilan['Conversion rate of shots on target'] = (Overall_Data_ACMilan['Goals scored'] / Overall_Data_ACMilan['Shots on target'])*100

#We round everything in the DataFrames to 2 decimal places:
Overall_Data_CLStats = Overall_Data_CLStats.round(decimals=2)
Overall_Data_ACMilan = Overall_Data_ACMilan.round(decimals=2)

# %%
Overall_Data_CLStats
# Out:
#       Season League position                   Team name  Total points  \
# 0  2013/2014               3                  SSC Napoli          78.0
# 1  2014/2015               3                    SS Lazio          69.0
# 2  2015/2016               3                     AS Roma          80.0
# 3  2016/2017               3                  SSC Napoli          86.0
# 4  2017/2018               3                     AS Roma          77.0
# 5  2018/2019               3  Atalanta Bergamasca Calcio          69.0
# 6  2013-2019             3rd                   UCL teams          76.5
#
#    Points per game  Matches played   Wins  Draws  Losses  Goals scored  \
# 0             2.05            38.0  23.00    9.0    6.00         77.00
# 1             1.82            38.0  21.00    6.0   11.00         71.00
# 2             2.11            38.0  23.00   11.0    4.00         83.00
# 3             2.26            38.0  26.00    8.0    4.00         94.00
# ...

# %%
Overall_Data_ACMilan
# Out:
#       Season League position Team name  Total points  Points per game  \
# 0  2013/2014               8  AC Milan         57.00             1.50
# 1  2014/2015              10  AC Milan         52.00             1.37
# 2  2015/2016               7  AC Milan         57.00             1.50
# 3  2016/2017               6  AC Milan         63.00             1.66
# 4  2017/2018               6  AC Milan         64.00             1.68
# 5  2018/2019               5  AC Milan         68.00             1.79
# 6  2013-2019              NA  AC Milan         60.17             1.58
#
#    Matches played  Wins  Draws  Losses  Goals scored  Goals conceded  \
# 0            38.0  16.0   9.00   13.00          57.0           49.00
# 1            38.0  13.0  13.00   12.00          56.0           50.00
# 2            38.0  15.0  12.00   11.00          49.0           43.00
# 3            38.0  18.0   9.00   11.00          57.0           45.00
# ...

# %%
#For the purpose of this study we need only the overall stats for the 6 seasons,
#So we limit the DataFrames to that last row: 

Overall_Data_CLStats = Overall_Data_CLStats.loc[Overall_Data_CLStats['Season'] == '2013-2019']
Overall_Data_ACMilan = Overall_Data_ACMilan.loc[Overall_Data_ACMilan['Season'] == '2013-2019']

#We join them together in one single DataFrame
Overall_Stats = pd.concat([Overall_Data_ACMilan, Overall_Data_CLStats])
Overall_Stats
# Out:
#       Season League position  Team name  Total points  Points per game  \
# 6  2013-2019              NA   AC Milan         60.17             1.58
# 6  2013-2019             3rd  UCL teams         76.50             2.02
#
#    Matches played   Wins  Draws  Losses  Goals scored  Goals conceded  \
# 6            38.0  16.50  10.67   10.83         55.00           44.17
# 6            38.0  22.67   8.50    6.83         77.17           38.50
#
#    Goal difference  Clean sheets  Failed to score  Goals scored per match  \
# 6            10.83         11.17             8.33                    1.45
# 6            38.67         12.33             6.17                    2.03
#
#    Goals conceded per match  Win %  Clean sheet %  Failed to score %  \
# 6                      1.16  43.17          29.67              22.00
# 6                      1.02  59.83          32.50              16.17
#
#    Number of cards  Average possession   Shots  Shots on target  \
# ...

# %%
#We plot the Overall_Stats DataFrame in a polar plot to compare AC Milan vs UCL Teams

import numpy as np
import pylab as pl

class Radar(object):
    def __init__(self, fig, titles, labels, rotation=0, rect=None):
        if rect is None:
            rect = [0.05, 0.05, 0.95, 0.95]

        self.n = len(titles)
        self.angles = np.arange(0, 360, 360.0/self.n)
        self.axes = [fig.add_axes(rect, projection="polar", label="axes%d" % i) 
                         for i in range(self.n)]

        self.ax = self.axes[0]
        self.ax.set_thetagrids(self.angles, labels=titles, fontsize=14)

        for ax in self.axes[1:]:
            ax.patch.set_visible(False)
            ax.grid("off")
            ax.xaxis.set_visible(False)

        for  ax, angle, label in zip(self.axes, self.angles, labels):
            ax.set_rgrids(range(1, 7), angle=angle, labels=label)
            ax.spines["polar"].set_visible(True)
            ax.set_ylim(0, 6)
            ax.set_theta_offset(np.deg2rad(rotation))

    def plot(self, values, *args, **kw):
        angle = np.deg2rad(np.r_[self.angles, self.angles[0]])
        values = np.r_[values, values[0]]
        self.ax.plot(angle, values, *args, **kw)
    
    def fill(self, values, *args, **kw):
        angle = np.deg2rad(np.r_[self.angles, self.angles[0]])
        values = np.r_[values, values[0]]
        self.ax.fill(angle, values, *args, **kw)    



fig = pl.figure(figsize=(8, 8))

titles = ['Points per game','Win %','Goals scored',
          'Goals conceded', 'Failed to score %', 'Shots',
          'Conversion rate of shots on target (%)', 'Conversion rate of shots (%)',
          'Shots on target', 'Average possession (%)']

labels = [[0.5, 1, 1.5, 2, 2.5], 
          [10, 20, 30, 40, 50],
          [30, 40, 50, 60, 70],
          [10, 20, 30, 40, 50],
          [10, 20, 30, 40, 50],
          [100, 200, 300, 400, 500],
          [15, 20, 25, 30, 35],
          [5, 10, 15, 20, 25],
          [210, 220, 230, 240, 250],
          [40, 50, 60, 70, 80]]

radar = Radar(fig, titles, labels)
radar.plot([3.15, 4.317, 3.5, 4.417, 2.2, 4.8967, 3.145, 2.24, 1.367, 2.3], "-", lw=2, color="r", alpha=0.8, label="AC Milan from 2013 to 2019")
radar.fill([3.15, 4.317, 3.5, 4.417, 2.2, 4.8967, 3.145, 2.24, 1.367, 2.3], color="r", alpha=0.1)

radar.plot([4.05, 5.983, 5.717, 3.85, 1.617, 5.4183, 4.41, 2.85, 4.083, 2.567],"-", lw=2, color="b", alpha=0.8, label="UCL teams from 2013 to 2019")
radar.fill([4.05, 5.983, 5.717, 3.85, 1.617, 5.4183, 4.41, 2.85, 4.083, 2.567], color="b", alpha=0.1)


radar.ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.10),
      fancybox=True, shadow=True, ncol=4, fontsize=13)
pl.title("2013-2019 Overall stats: AC Milan vs UCL teams",fontsize=25,color="tomato")
# Out:
# C:\Users\pabl_\Anaconda3\lib\site-packages\matplotlib\cbook\deprecation.py:107: MatplotlibDeprecationWarning: Passing one of 'on', 'true', 'off', 'false' as a boolean is deprecated; use an actual boolean (True/False) instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
# Text(0.5,1.05,'2013-2019 Overall stats: AC Milan vs UCL teams')

# %% [markdown]
# With this plot we can visualize Milan's and UCL team's overall stats from 2013 to 2019, and have a better understanding on why Milan hasn't made it to Champions League. Let's have a look at the data:
#
# Starting with the Win %, UCL teams have won an average of around 17% more games than Milan, which is a huge amount considering how competitive the league is and how tight the fight for these european spots is. Every point counts, so it is obvious to say 43% of wins in a season is not enough (UCL teams reach almost 60%).
#
# We then move on to what I believe has been one of Milan's biggest weaknesses throughout the years; Goals scored. On average, the third qualified in the league has scored almost 22 more goals a season than Milan. That is an absurd amount given the fact Milan has one of the highest budgets of the competition and should be able to afford good strikers.
#
# They have also conceded more goals than UCL teams, but not many more, which makes me stress even more the fact the problem comes from their attacking performances.
#
# Finally, we have a closer look at their main attacking statistics: By looking at the amount of shots, shots on target, and their conversion rates we can analyze the effectiveness of the team.
#
# Besides taking roughly 50 more shots on average than Milan, UCL teams are way more effective in front of goal. Although their conversion rate of total shots isn't spectacular (around 14%), their conversion rate of shots on target is actually very impressive; little over 32%, meaning just over one of every three efforts finds the back of the net.
# On the other side, on top of having less shots Milan also appears to be less effective by quite a bit (shots conversion rate of around 11% and 26% of shots on target).
#
# The fact average possession is very similar between Milan and UCL teams is important, as it tells us they pretty much have the ball the same amount of time. The difference is UCL teams actually manage to create chances and goal opportunities, and are way more clinical in front of goal.

# %% [markdown]
# We now prepare a dataset with Milan's overall stats from the last 2 seasons, which we will use as KPIs in order to look for teams with similar characteristics and thus style of play:

# %%
#We create a dataset with some of Milans overall stats from last 2 seasons:

Milan2017_19 = Data_ACMilan.iloc[[5,6], :]
Milan2017_19 = Milan2017_19[['Points per game', 'Goals scored', 'Goals conceded', 'Goal difference', 'Goals scored per match', 'Goals conceded per match', 'Clean sheet %', 'Number of cards', 'Average possession', 'Shots', 'Shots on target', 'Fouls']]

Milan2017_19['Conversion rate of shots'] = (Milan2017_19['Goals scored'] / Milan2017_19['Shots'])*100
Milan2017_19['Conversion rate of shots on target'] = (Milan2017_19['Goals scored'] / Milan2017_19['Shots on target'])*100


Milan2017_19
# Out:
#    Points per game  Goals scored  Goals conceded  Goal difference  \
# 7             1.68            56              42               14
# 7             1.79            55              36               19
#
#    Goals scored per match  Goals conceded per match  Clean sheet %  \
# 7                    1.47                      1.11             32
# 7                    1.45                      0.95             32
#
#    Number of cards  Average possession  Shots  Shots on target  Fouls  \
# 7               81                  55    582              276    478
# 7               88                  53    629              243    425
#
#    Conversion rate of shots  Conversion rate of shots on target
# 7                  9.621993                           20.289855
# 7                  8.744038                           22.633745

# %%
#We import, clean, and prepare data from 5 big leagues in europe for the 2018-19 season:
#As we did earlier, we create and add the 'Total points', 'Conversion rate of shots', and
#Conversion rate of shots on target' columns:

#Spain
SpainData = pd.read_csv("spain-la-liga-teams-2018-to-2019-stats.csv")
pd.options.display.max_columns = None
SpainData = SpainData[['season', 'league_position', 'team_name', 'points_per_game', 'matches_played', 'wins', 'draws', 'losses','goals_scored', 'goals_conceded', 'goal_difference', 'clean_sheets', 'fts_count', 'goals_scored_per_match', 'goals_conceded_per_match', 'win_percentage', 'clean_sheet_percentage', 'fts_percentage', 'cards_total', 'average_possession', 'shots', 'shots_on_target', 'shots_off_target', 'fouls',]].sort_values(by='league_position', ascending=True)
SpainData = SpainData.rename(columns = {'season':'Season', 'league_position':'League position', 'team_name':'Team name', 'points_per_game':'Points per game', 'matches_played':'Matches played', 'wins':'Wins', 'draws':'Draws', 'losses':'Losses', 'goals_scored':'Goals scored', 'goals_conceded':'Goals conceded', 'goal_difference':'Goal difference', 'clean_sheets':'Clean sheets', 'fts_count':'Failed to score', 'goals_scored_per_match':'Goals scored per match', 'goals_conceded_per_match':'Goals conceded per match', 'win_percentage':'Win %', 'clean_sheet_percentage':'Clean sheet %', 'fts_percentage':'Failed to score %', 'cards_total':'Number of cards','average_possession':'Average possession', 'shots':'Shots', 'shots_on_target':'Shots on target', 'shots_off_target':'Shots off target', 'fouls':'Fouls'})

SpainData['Total points'] = SpainData['Wins']*3 + SpainData['Draws']
SpainData = SpainData[['Season', 'League position', 'Team name', 'Total points', 'Points per game', 'Goals scored', 'Goals conceded', 'Goal difference', 'Goals scored per match', 'Goals conceded per match', 'Clean sheet %', 'Number of cards', 'Average possession', 'Shots', 'Shots on target', 'Fouls']]

SpainData['Conversion rate of shots'] = (SpainData['Goals scored'] / SpainData['Shots'])*100
SpainData['Conversion rate of shots on target'] = (SpainData['Goals scored'] / SpainData['Shots on target'])*100

#Germany
GermanyData = pd.read_csv("germany-bundesliga-teams-2018-to-2019-stats.csv")
pd.options.display.max_columns = None
GermanyData = GermanyData[['season', 'league_position', 'team_name', 'points_per_game', 'matches_played', 'wins', 'draws', 'losses','goals_scored', 'goals_conceded', 'goal_difference', 'clean_sheets', 'fts_count', 'goals_scored_per_match', 'goals_conceded_per_match', 'win_percentage', 'clean_sheet_percentage', 'fts_percentage', 'cards_total', 'average_possession', 'shots', 'shots_on_target', 'shots_off_target', 'fouls',]].sort_values(by='league_position', ascending=True)
GermanyData = GermanyData.rename(columns = {'season':'Season', 'league_position':'League position', 'team_name':'Team name', 'points_per_game':'Points per game', 'matches_played':'Matches played', 'wins':'Wins', 'draws':'Draws', 'losses':'Losses', 'goals_scored':'Goals scored', 'goals_conceded':'Goals conceded', 'goal_difference':'Goal difference', 'clean_sheets':'Clean sheets', 'fts_count':'Failed to score', 'goals_scored_per_match':'Goals scored per match', 'goals_conceded_per_match':'Goals conceded per match', 'win_percentage':'Win %', 'clean_sheet_percentage':'Clean sheet %', 'fts_percentage':'Failed to score %', 'cards_total':'Number of cards','average_possession':'Average possession', 'shots':'Shots', 'shots_on_target':'Shots on target', 'shots_off_target':'Shots off target', 'fouls':'Fouls'})

GermanyData['Total points'] = GermanyData['Wins']*3 + GermanyData['Draws']
GermanyData = GermanyData[['Season', 'League position', 'Team name', 'Total points', 'Points per game', 'Goals scored', 'Goals conceded', 'Goal difference', 'Goals scored per match', 'Goals conceded per match', 'Clean sheet %', 'Number of cards', 'Average possession', 'Shots', 'Shots on target', 'Fouls']]

GermanyData['Conversion rate of shots'] = (GermanyData['Goals scored'] / GermanyData['Shots'])*100
GermanyData['Conversion rate of shots on target'] = (GermanyData['Goals scored'] / GermanyData['Shots on target'])*100

#France
FranceData = pd.read_csv("france-ligue-1-teams-2018-to-2019-stats.csv")
pd.options.display.max_columns = None
FranceData = FranceData[['season', 'league_position', 'team_name', 'points_per_game', 'matches_played', 'wins', 'draws', 'losses','goals_scored', 'goals_conceded', 'goal_difference', 'clean_sheets', 'fts_count', 'goals_scored_per_match', 'goals_conceded_per_match', 'win_percentage', 'clean_sheet_percentage', 'fts_percentage', 'cards_total', 'average_possession', 'shots', 'shots_on_target', 'shots_off_target', 'fouls',]].sort_values(by='league_position', ascending=True)
FranceData = FranceData.rename(columns = {'season':'Season', 'league_position':'League position', 'team_name':'Team name', 'points_per_game':'Points per game', 'matches_played':'Matches played', 'wins':'Wins', 'draws':'Draws', 'losses':'Losses', 'goals_scored':'Goals scored', 'goals_conceded':'Goals conceded', 'goal_difference':'Goal difference', 'clean_sheets':'Clean sheets', 'fts_count':'Failed to score', 'goals_scored_per_match':'Goals scored per match', 'goals_conceded_per_match':'Goals conceded per match', 'win_percentage':'Win %', 'clean_sheet_percentage':'Clean sheet %', 'fts_percentage':'Failed to score %', 'cards_total':'Number of cards','average_possession':'Average possession', 'shots':'Shots', 'shots_on_target':'Shots on target', 'shots_off_target':'Shots off target', 'fouls':'Fouls'})

FranceData['Total points'] = FranceData['Wins']*3 + FranceData['Draws']
FranceData = FranceData[['Season', 'League position', 'Team name', 'Total points', 'Points per game', 'Goals scored', 'Goals conceded', 'Goal difference', 'Goals scored per match', 'Goals conceded per match', 'Clean sheet %', 'Number of cards', 'Average possession', 'Shots', 'Shots on target', 'Fouls']]

FranceData['Conversion rate of shots'] = (FranceData['Goals scored'] / FranceData['Shots'])*100
FranceData['Conversion rate of shots on target'] = (FranceData['Goals scored'] / FranceData['Shots on target'])*100

#England
EnglandData = pd.read_csv("england-premier-league-teams-2018-to-2019-stats.csv")
pd.options.display.max_columns = None
EnglandData = EnglandData[['season', 'league_position', 'team_name', 'points_per_game', 'matches_played', 'wins', 'draws', 'losses','goals_scored', 'goals_conceded', 'goal_difference', 'clean_sheets', 'fts_count', 'goals_scored_per_match', 'goals_conceded_per_match', 'win_percentage', 'clean_sheet_percentage', 'fts_percentage', 'cards_total', 'average_possession', 'shots', 'shots_on_target', 'shots_off_target', 'fouls',]].sort_values(by='league_position', ascending=True)
EnglandData = EnglandData.rename(columns = {'season':'Season', 'league_position':'League position', 'team_name':'Team name', 'points_per_game':'Points per game', 'matches_played':'Matches played', 'wins':'Wins', 'draws':'Draws', 'losses':'Losses', 'goals_scored':'Goals scored', 'goals_conceded':'Goals conceded', 'goal_difference':'Goal difference', 'clean_sheets':'Clean sheets', 'fts_count':'Failed to score', 'goals_scored_per_match':'Goals scored per match', 'goals_conceded_per_match':'Goals conceded per match', 'win_percentage':'Win %', 'clean_sheet_percentage':'Clean sheet %', 'fts_percentage':'Failed to score %', 'cards_total':'Number of cards','average_possession':'Average possession', 'shots':'Shots', 'shots_on_target':'Shots on target', 'shots_off_target':'Shots off target', 'fouls':'Fouls'})

EnglandData['Total points'] = EnglandData['Wins']*3 + EnglandData['Draws']
EnglandData = EnglandData[['Season', 'League position', 'Team name', 'Total points', 'Points per game', 'Goals scored', 'Goals conceded', 'Goal difference', 'Goals scored per match', 'Goals conceded per match', 'Clean sheet %', 'Number of cards', 'Average possession', 'Shots', 'Shots on target', 'Fouls']]

EnglandData['Conversion rate of shots'] = (EnglandData['Goals scored'] / EnglandData['Shots'])*100
EnglandData['Conversion rate of shots on target'] = (EnglandData['Goals scored'] / EnglandData['Shots on target'])*100

#Italy
ItalyData = pd.read_csv("italy-serie-a-teams-2018-to-2019-stats.csv")
pd.options.display.max_columns = None
ItalyData = ItalyData[['season', 'league_position', 'team_name', 'points_per_game', 'matches_played', 'wins', 'draws', 'losses','goals_scored', 'goals_conceded', 'goal_difference', 'clean_sheets', 'fts_count', 'goals_scored_per_match', 'goals_conceded_per_match', 'win_percentage', 'clean_sheet_percentage', 'fts_percentage', 'cards_total', 'average_possession', 'shots', 'shots_on_target', 'shots_off_target', 'fouls',]].sort_values(by='league_position', ascending=True)
ItalyData = ItalyData.rename(columns = {'season':'Season', 'league_position':'League position', 'team_name':'Team name', 'points_per_game':'Points per game', 'matches_played':'Matches played', 'wins':'Wins', 'draws':'Draws', 'losses':'Losses', 'goals_scored':'Goals scored', 'goals_conceded':'Goals conceded', 'goal_difference':'Goal difference', 'clean_sheets':'Clean sheets', 'fts_count':'Failed to score', 'goals_scored_per_match':'Goals scored per match', 'goals_conceded_per_match':'Goals conceded per match', 'win_percentage':'Win %', 'clean_sheet_percentage':'Clean sheet %', 'fts_percentage':'Failed to score %', 'cards_total':'Number of cards','average_possession':'Average possession', 'shots':'Shots', 'shots_on_target':'Shots on target', 'shots_off_target':'Shots off target', 'fouls':'Fouls'})

ItalyData['Total points'] = ItalyData['Wins']*3 + ItalyData['Draws']
ItalyData = ItalyData[['Season', 'League position', 'Team name', 'Total points', 'Points per game', 'Goals scored', 'Goals conceded', 'Goal difference', 'Goals scored per match', 'Goals conceded per match', 'Clean sheet %', 'Number of cards', 'Average possession', 'Shots', 'Shots on target', 'Fouls']]

ItalyData['Conversion rate of shots'] = (ItalyData['Goals scored'] / ItalyData['Shots'])*100
ItalyData['Conversion rate of shots on target'] = (ItalyData['Goals scored'] / ItalyData['Shots on target'])*100

# %%
#example:

EnglandData
# Out:
#        Season  League position                   Team name  Total points  \
# 2   2018/2019                1          Manchester City FC            98
# 10  2018/2019                2                Liverpool FC            97
# 11  2018/2019                3                  Chelsea FC            72
# 1   2018/2019                4        Tottenham Hotspur FC            71
# 0   2018/2019                5                  Arsenal FC            70
# 9   2018/2019                6        Manchester United FC            66
# 19  2018/2019                7  Wolverhampton Wanderers FC            57
# 5   2018/2019                8                  Everton FC            54
# 3   2018/2019                9           Leicester City FC            52
# 12  2018/2019               10          West Ham United FC            52
# 13  2018/2019               11                  Watford FC            50
# 4   2018/2019               12           Crystal Palace FC            49
# ...

# %% [markdown]
# We filter our data according to the statistics we are looking for. I am looking for teams with a possession % similar to Milan's (so the potential recruit can better adapt to Milan's style of play), similar amount of goals or more (between 50 and 80 goals), and better conversion rates for shots and shots on target, meaning we are looking at teams with some similar characteristics than Milan but at the same time more clinical in front of goal, in order to look at players who could potentially improve Milan's effectiveness:

# %%
ItalyFilteredData = ItalyData[(ItalyData['Average possession'] > 45) & (ItalyData['Average possession'] < 56) & (ItalyData['Goals scored'] > 50) 
                              & (ItalyData['Goals scored'] < 80) & (ItalyData['Conversion rate of shots'] > 10) & (ItalyData['Conversion rate of shots on target'] > 23)]

SpainFilteredData = SpainData[(SpainData['Average possession'] > 45) & (SpainData['Average possession'] < 56) & (SpainData['Goals scored'] > 50) 
                              & (SpainData['Goals scored'] < 80) & (SpainData['Conversion rate of shots'] > 10) & (SpainData['Conversion rate of shots on target'] > 23)]

FranceFilteredData = FranceData[(FranceData['Average possession'] > 45) & (FranceData['Average possession'] < 56) & (FranceData['Goals scored'] > 50) 
                              & (FranceData['Goals scored'] < 80) & (FranceData['Conversion rate of shots'] > 10) & (FranceData['Conversion rate of shots on target'] > 23)]

GermanyFilteredData = GermanyData[(GermanyData['Average possession'] > 45) & (GermanyData['Average possession'] < 56) & (GermanyData['Goals scored'] > 50) 
                              & (GermanyData['Goals scored'] < 80) & (GermanyData['Conversion rate of shots'] > 10) & (GermanyData['Conversion rate of shots on target'] > 23)]

EnglandFilteredData = EnglandData[(EnglandData['Average possession'] > 45) & (EnglandData['Average possession'] < 56) & (EnglandData['Goals scored'] > 50) 
                              & (EnglandData['Goals scored'] < 80) & (EnglandData['Conversion rate of shots'] > 10) & (EnglandData['Conversion rate of shots on target'] > 23)]


FiveLeagues_FilteredData = pd.concat([ItalyFilteredData, SpainFilteredData, FranceFilteredData, 
                                      GermanyFilteredData, EnglandFilteredData])
FiveLeagues_FilteredData
# Out:
#        Season  League position                     Team name  Total points  \
# 10  2018/2019                9                  UC Sampdoria            53
# 4   2018/2019                2       Club Atlético de Madrid            76
# 12  2018/2019                4                   Valencia CF            61
# 3   2018/2019                5                    Sevilla FC            59
# 15  2018/2019               15                    Levante UD            44
# 9   2018/2019               16       Real Club Celta de Vigo            41
# 10  2018/2019                2           Lille OSC Métropole            75
# 5   2018/2019                4              AS Saint-Étienne            66
# 12  2018/2019                5        Olympique de Marseille            61
# 6   2018/2019                6               Montpellier HSC            59
# 19  2018/2019                9               Nîmes Olympique            53
# ...

# %% [markdown]
# We conduct a research across all 5 biggest European leagues (French, Spanish, English, Italian and German) and as a result we get the list above of 25 teams with the statistics we are looking for.

# %% [markdown]
# ## PLAYERS STATS ANALYSIS:

# %% [markdown]
# The next step is pulling out a list of players from the teams above (in this case Forwards and Midfielders, as those are the positions Milan needs to score more goals).
#
# The objective is to get a list focusing only on players with 7 or more goals and/or assists, as we want players who could have a direct impact on the team. The list will be called "Potential recruits":

# %%
#Create new DataFrame with players stats for 2018-19 season with only the columns we want:
import pandas as pd
pd.options.display.max_rows = None

#Serie A:
ItalyPlayers = pd.read_csv("italy-serie-a-players-2018-to-2019-stats.csv")
ItalyPlayers = ItalyPlayers[['full_name', 'season', 'position', 'Current Club', 'minutes_played_overall', 'goals_overall', 'assists_overall', 'clean_sheets_overall', 'conceded_overall', 'yellow_cards_overall', 'red_cards_overall', 'goals_involved_per_90_overall', 'assists_per_90_overall', 'goals_per_90_overall', 'conceded_per_90_overall', 'cards_per_90_overall']].sort_values(by='position')
ItalyPlayers = ItalyPlayers.rename(columns = {'full_name':'Full name', 'season':'Season', 'position':'Position', 'Current Club':'Current club', 'minutes_played_overall':'Minutes played', 'goals_overall':'Goals', 'assists_overall':'Assists', 'clean_sheets_overall':'Clean sheets', 'conceded_overall':'Goals conceded', 'yellow_cards_overall':'Yellow cards', 'red_cards_overall':'Red cards', 'goals_involved_per_90_overall':'Goals involved per 90min', 'assists_per_90_overall':'Assists per 90min', 'goals_per_90_overall':'Goals per 90min', 'conceded_per_90_overall':'Goals conceded per 90min', 'cards_per_90_overall':'Cards per 90min'})

#Bundesliga:
GermanyPlayers = pd.read_csv("germany-bundesliga-players-2018-to-2019-stats.csv")
GermanyPlayers = GermanyPlayers[['full_name', 'season', 'position', 'Current Club', 'minutes_played_overall', 'goals_overall', 'assists_overall', 'clean_sheets_overall', 'conceded_overall', 'yellow_cards_overall', 'red_cards_overall', 'goals_involved_per_90_overall', 'assists_per_90_overall', 'goals_per_90_overall', 'conceded_per_90_overall', 'cards_per_90_overall']].sort_values(by='position')
GermanyPlayers = GermanyPlayers.rename(columns = {'full_name':'Full name', 'season':'Season', 'position':'Position', 'Current Club':'Current club', 'minutes_played_overall':'Minutes played', 'goals_overall':'Goals', 'assists_overall':'Assists', 'clean_sheets_overall':'Clean sheets', 'conceded_overall':'Goals conceded', 'yellow_cards_overall':'Yellow cards', 'red_cards_overall':'Red cards', 'goals_involved_per_90_overall':'Goals involved per 90min', 'assists_per_90_overall':'Assists per 90min', 'goals_per_90_overall':'Goals per 90min', 'conceded_per_90_overall':'Goals conceded per 90min', 'cards_per_90_overall':'Cards per 90min'})

#La Liga:
SpainPlayers = pd.read_csv("spain-la-liga-players-2018-to-2019-stats.csv")
SpainPlayers = SpainPlayers[['full_name', 'season', 'position', 'Current Club', 'minutes_played_overall', 'goals_overall', 'assists_overall', 'clean_sheets_overall', 'conceded_overall', 'yellow_cards_overall', 'red_cards_overall', 'goals_involved_per_90_overall', 'assists_per_90_overall', 'goals_per_90_overall', 'conceded_per_90_overall', 'cards_per_90_overall']].sort_values(by='position')
SpainPlayers = SpainPlayers.rename(columns = {'full_name':'Full name', 'season':'Season', 'position':'Position', 'Current Club':'Current club', 'minutes_played_overall':'Minutes played', 'goals_overall':'Goals', 'assists_overall':'Assists', 'clean_sheets_overall':'Clean sheets', 'conceded_overall':'Goals conceded', 'yellow_cards_overall':'Yellow cards', 'red_cards_overall':'Red cards', 'goals_involved_per_90_overall':'Goals involved per 90min', 'assists_per_90_overall':'Assists per 90min', 'goals_per_90_overall':'Goals per 90min', 'conceded_per_90_overall':'Goals conceded per 90min', 'cards_per_90_overall':'Cards per 90min'})

#Ligue 1:
FrancePlayers = pd.read_csv("france-ligue-1-players-2018-to-2019-stats.csv")
FrancePlayers = FrancePlayers[['full_name', 'season', 'position', 'Current Club', 'minutes_played_overall', 'goals_overall', 'assists_overall', 'clean_sheets_overall', 'conceded_overall', 'yellow_cards_overall', 'red_cards_overall', 'goals_involved_per_90_overall', 'assists_per_90_overall', 'goals_per_90_overall', 'conceded_per_90_overall', 'cards_per_90_overall']].sort_values(by='position')
FrancePlayers = FrancePlayers.rename(columns = {'full_name':'Full name', 'season':'Season', 'position':'Position', 'Current Club':'Current club', 'minutes_played_overall':'Minutes played', 'goals_overall':'Goals', 'assists_overall':'Assists', 'clean_sheets_overall':'Clean sheets', 'conceded_overall':'Goals conceded', 'yellow_cards_overall':'Yellow cards', 'red_cards_overall':'Red cards', 'goals_involved_per_90_overall':'Goals involved per 90min', 'assists_per_90_overall':'Assists per 90min', 'goals_per_90_overall':'Goals per 90min', 'conceded_per_90_overall':'Goals conceded per 90min', 'cards_per_90_overall':'Cards per 90min'})

#Premier League:
EnglandPlayers = pd.read_csv("england-premier-league-players-2018-to-2019-stats (1).csv")
EnglandPlayers = EnglandPlayers[['full_name', 'season', 'position', 'Current Club', 'minutes_played_overall', 'goals_overall', 'assists_overall', 'clean_sheets_overall', 'conceded_overall', 'yellow_cards_overall', 'red_cards_overall', 'goals_involved_per_90_overall', 'assists_per_90_overall', 'goals_per_90_overall', 'conceded_per_90_overall', 'cards_per_90_overall']].sort_values(by='position')
EnglandPlayers = EnglandPlayers.rename(columns = {'full_name':'Full name', 'season':'Season', 'position':'Position', 'Current Club':'Current club', 'minutes_played_overall':'Minutes played', 'goals_overall':'Goals', 'assists_overall':'Assists', 'clean_sheets_overall':'Clean sheets', 'conceded_overall':'Goals conceded', 'yellow_cards_overall':'Yellow cards', 'red_cards_overall':'Red cards', 'goals_involved_per_90_overall':'Goals involved per 90min', 'assists_per_90_overall':'Assists per 90min', 'goals_per_90_overall':'Goals per 90min', 'conceded_per_90_overall':'Goals conceded per 90min', 'cards_per_90_overall':'Cards per 90min'})

#We want only the Forwards and Midfielders from the FiveLeagues_FilteredData teams,
#and only focus on those with 7 or more goals and/or assists:
PotentialRecruits = pd.concat([ItalyPlayers, GermanyPlayers, SpainPlayers, FrancePlayers, EnglandPlayers])
PotentialRecruits = PotentialRecruits[(PotentialRecruits['Position']=='Forward') | (PotentialRecruits['Position']=='Midfielder')]
PotentialRecruits = PotentialRecruits[(PotentialRecruits['Goals'] >= 7) | (PotentialRecruits['Assists'] >= 7)]
PotentialRecruits = PotentialRecruits[(PotentialRecruits['Current club']=='Sampdoria') | 
               (PotentialRecruits['Current club']=='Atlético Madrid') | 
               (PotentialRecruits['Current club']=='Valencia CF') | 
               (PotentialRecruits['Current club']=='Sevilla FC') | 
               (PotentialRecruits['Current club']=='Levante UD') | 
               (PotentialRecruits['Current club']=='Celta de Vigo') | 
               (PotentialRecruits['Current club']=='Lille') | 
               (PotentialRecruits['Current club']=='Saint-Étienne') | 
               (PotentialRecruits['Current club']=='Olympique Marseille') | 
               (PotentialRecruits['Current club']=='Montpellier') | 
               (PotentialRecruits['Current club']=='Nîmes') | 
               (PotentialRecruits['Current club']=='Rennes') | 
               (PotentialRecruits['Current club']=='Strasbourg') | 
               (PotentialRecruits['Current club']=='RB Leipzig') | 
               (PotentialRecruits['Current club']=="Borussia M'gladbach") | 
               (PotentialRecruits['Current club']=='Wolfsburg') | 
               (PotentialRecruits['Current club']=='Eintracht Frankfurt') | 
               (PotentialRecruits['Current club']=='Werder Bremen') | 
               (PotentialRecruits['Current club']=='Hoffenheim') | 
               (PotentialRecruits['Current club']=='Augsburg') | 
               (PotentialRecruits['Current club']=='Manchester United') | 
               (PotentialRecruits['Current club']=='Everton') | 
               (PotentialRecruits['Current club']=='West Ham United') | 
               (PotentialRecruits['Current club']=='Watford') | 
               (PotentialRecruits['Current club']=='AFC Bournemouth')].sort_values(by='Goals', ascending=False)

# %%
PotentialRecruits
# Out:
#                                Full name     Season    Position  \
# 253                   Fabio Quagliarella  2018/2019     Forward
# 181                         Nicolas Pépé  2018/2019     Forward
# 80                            Iago Aspas  2018/2019     Forward
# 249                    Wissam Ben Yedder  2018/2019     Forward
# 329                        Wout Weghorst  2018/2019     Forward
# 315                           Luka Jović  2018/2019     Forward
# 147                      Andrej Kramarić  2018/2019     Forward
# 345                       Ishak Belfodil  2018/2019     Forward
# 95                       Florian Thauvin  2018/2019  Midfielder
# 155                          Timo Werner  2018/2019     Forward
# 326                     Sébastien Haller  2018/2019     Forward
# 315                    Antoine Griezmann  2018/2019     Forward
# 512                       Yussuf Poulsen  2018/2019     Forward
# 81                         Callum Wilson  2018/2019     Forward
# ...

# %% [markdown]
# We get a DataSet with 77 players Milan could potentially recruit in order to improve its Goals ratio.
#
# A lot of aspects come into play when recruiting a player (position, age, technical ability, player's mentality, coaches/players demands, club's economical situation, etc.), but from a football statistical point of view I do believe a very good amount of players appearing on this list would be a great fit for AC Milan.
#
# As a matter of fact, AC Milan bought 3 players appearing on the list for the 2019-2020 season: the forward <span style="color: red;">André Silva</span>, who scored 9 goals in 2018-2019 for Sevilla, went back to AC Milan for the 2019-20 season following his good year at the spanish club (as he was loaned out to Sevilla in 2018). He was loaned out again to another club after doing the pre-season with the Italian giants. AC Milan also bought <span style="color: red;">Ante Rebic</span> from Eintracht Frankfurt (after scoring 9 goals and giving 4 assists) and <span style="color: red;">Rafael Leao</span> (a forward from Lille who scored 8 goals and had 3 assits).
#
# We can thus see how this generated dataset is indeed valuable and provides us with real possibilities for AC Milan.

# %%
import seaborn as sns

goals = PotentialRecruits.groupby("Full name")["Goals"].sum().reset_index().sort_values(by = "Goals", ascending = False)
assists = PotentialRecruits.groupby("Full name")["Assists"].sum().reset_index().sort_values(by = "Assists", ascending = False)

plt.figure(figsize=(13, 10))

plt.subplot(121)
ax = sns.barplot(x="Goals",y="Full name",
                 data=goals[:55],palette="rainbow",
                linewidth = 1,edgecolor = "k"*55)
plt.ylabel('')
plt.title("Players with highest total goals in 2018-2019", fontsize = 15, color = 'r')
for i,j in enumerate(goals["Goals"][:55]):
    ax.text(.7,i,j,weight="bold")

plt.subplot(122)
ax = sns.barplot(x="Assists",y="Full name",
                 data=assists[:44],palette="rainbow",
                linewidth = 1,edgecolor = "k"*44)
plt.ylabel('')
plt.subplots_adjust(wspace = .4)
plt.title("Players with highest total assists in 2018-2019", fontsize = 15, color = 'r')
for i,j in enumerate(assists["Assists"][:44]):
    ax.text(.7,i,j,weight="bold")

# %% [markdown]
# The bar plots above show the top players of the PotentialRecruits DataSet by their goals and assists.

# %% [markdown]
# ## SIMPLE PREDICTIONS WITH LINEAR REGRESSION:

# %% [markdown]
# In this section, the objective is to make some predictions about the possible impact a specific player could have on AC Milan’s team given his statistics, and how would the club benefit by signing him.
#
# Again, this is purely based on statistics from the past (and limited ones). We know football is a very dynamic and changing game, and its nature limits how accurate our predictions might be.
#
# This study will show us, based on Milan’s statistics for the past 7 years, how many games would they win if they added a certain player to their squad (if they added to their goal difference from last season the goals he was involved in last season (goals + assists)).
#
# We will keep adding explanations throughout the section to have a better understanding of the data that is being used.

# %% [markdown]
# ## CHECKING FOR LINEARITY:

# %% [markdown]
# Before executing a linear regression model, it is advisable to validate that certain assumptions are met.
#
# In this case we are going to check that a linear relationship exists between the dependent variable 'Wins' and the independent variable 'Goal difference' which is nothing but the difference between the goals scored and the goals conceded (the more a team scores and the less it concedes, the bigger its Goal difference).
#
# To perform this linearity check we will use a scatter diagram (utilizing the matplotlib library) to plot the relationship between 'Wins' and 'Goal difference':

# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.scatter(Data_ACMilan['Goal difference'], Data_ACMilan['Wins'], color='red')
plt.title('Goal difference vs Wins', fontsize=14)
plt.xlabel('Goal difference', fontsize=14)
plt.ylabel('Wins', fontsize=14)
plt.grid(True)
plt.show()

# %% [markdown]
# We notice that indeed a linear relationship exists between Milan's Wins and its Goal difference. Specifically, when Goal differences go up (more goals scored and less conceded), the number of Wins also goes up.

# %% [markdown]
# ## PERFORMING THE LINEAR REGRESSION:

# %% [markdown]
# We then perform predictions based on previous results and statistics.
#
# In this case, we look at Milan's last season's Goal difference (19), number of Wins (19 also), and ask ourselves:
#
# If they added the goals a potential recruit was involved in to their season, how many wins would they have if the remaining stats (Goals conceded) remained the same?
#
# In other words if they improved their attack and kept the same exact defensive stats, how many wins would they have?
#
# As stated, we see that for the 2018-2019 season Milan won 19 games, scored 55 goals and conceded 36, which left them with a goal difference of 19:

# %%
Data_ACMilan.loc[Data_ACMilan['Season']=='2018/2019']
# Out:
#       Season  League position Team name  Total points  Points per game  \
# 7  2018/2019                5  AC Milan            68             1.79
#
#    Matches played  Wins  Draws  Losses  Goals scored  Goals conceded  \
# 7              38    19     11       8            55              36
#
#    Goal difference  Clean sheets  Failed to score  Goals scored per match  \
# 7               19            12                9                    1.45
#
#    Goals conceded per match  Win %  Clean sheet %  Failed to score %  \
# 7                      0.95     50             32                 24
#
#    Number of cards  Average possession  Shots  Shots on target  \
# 7               88                  53    629              243
#
#    Shots off target  Fouls
# 7               386    425

# %% [markdown]
# We then create a function which adds the goals a potential recruit was involved in to Milan's goal difference amount (we add the goals and assists of Eintracht Frankfurt's forward Ante Rebić, who scored 9 goals and had 4 assists, thus was involved in 13 goals that season):

# %%
def GoalDifference():
    Goal_Difference = 19
    name = input("Insert player's name: ")
    
    def playerinfluence():
        PotentialRecruits['Goals involved'] = PotentialRecruits['Goals'] + PotentialRecruits['Assists']
        return PotentialRecruits[PotentialRecruits['Full name'].str.contains(name)][['Goals involved']]
    
    PotentialRecruits['New goal difference'] = Goal_Difference + PotentialRecruits[PotentialRecruits['Full name'].str.contains(name)][['Goals involved']]
    return PotentialRecruits[PotentialRecruits['Full name'].str.contains(name)][['New goal difference']]

# %%
GoalDifference()
# Out:
# Insert player's name: Ante Rebić
#      New goal difference
# 176                 32.0

# %% [markdown]
# The function returns a New goal difference of 32 (Milan's 19 goal difference + Ante Rebić's 13 goals involved).
#
# From that, we can add the data into Python and use sklearn to get the regression results:

# %%
import pandas as pd
from sklearn import linear_model
import statsmodels.api as sm


X = Data_ACMilan[['Goal difference']] # here we have 1 variable for linear regression.
Y = Data_ACMilan['Wins']
 
# with sklearn
regr = linear_model.LinearRegression()
regr.fit(X, Y)

print('Intercept: \n', regr.intercept_)
print('Coefficients: \n', regr.coef_)

#linear regression equation:
print('\nLinear Regression equation:\n', regr.intercept_, 
      '+', regr.coef_, '* New Goal Difference')

# prediction with sklearn
New_Goal_Difference = 32
print ('\n With a Goal difference of', New_Goal_Difference, 
       'AC Milan is predicted to win this amount of games: \n',
       regr.predict([[New_Goal_Difference]]))
# Out:
# Intercept:
#  13.050778354336543
# Coefficients:
#  [0.30800593]
#
# Linear Regression equation:
#  13.050778354336543 + [0.30800593] * New Goal Difference
#
#  With a Goal difference of 32 AC Milan is predicted to win this amount of games:
#  [22.90696812]

# %% [markdown]
# It is needless to say that with Ante Rebić's stats AC Milan would've done better in the league.
# Only 2 teams had more than 20 wins last season, meaning Milan would've been up there fighting with the best.

# %% [markdown]
# We could've performed a Multiple Linear Regression by adding more independent variables like 'Goals scored', 'Average possession', 'Shots', 'Conversion rate of shots', etc. To see how all of those stats combined influence the dependend variable 'Wins'.
#
# But the purpose of the exercise was to see how big of an impact a potential recruit would have on AC Milan, So I would've liked having more individual stats of the potential recruits (like amount of passes, shots, shots on target, tackles, crosses, etc.) and use them in a multiple linear regression rather than using AC Milan's stats.
#
# Our simple linear regression showed how the direct relation between a player's goals involved and the team's goal difference affects the wins of the team.
